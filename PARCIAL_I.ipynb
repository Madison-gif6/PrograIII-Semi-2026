# %% [markdown]
# <a href="https://colab.research.google.com/github/Madison-gif6/PrograIII-Semi-2026/blob/PALCIAL-I/PARCIAL_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1- IMPUESTO A LAS ACTIVIDADES ECONOMICAS

# %%
# Tabla de rangos: (desde, hasta, precio, adicional)
tabla_impuestos = [
    (0.01,        500,        1.5,   0),
    (500.01,      1000,       1.5,   3),
    (1000.01,     2000,       3,     3),
    (2000.01,     3000,       6,     3),
    (3000.01,     6000,       9,     2),
    (6000.01,     8000,       9,     2),
    (8000.01,     18000,      15,    2),
    (18000.01,    30000,      39,    2),
    (30000.01,    60000,      63,    1),
    (60000.01,    100000,     93,    0.8),
    (100000.01,   200000,     125,   0.7),
    (200000.01,   300000,     195,   0.6),
    (300000.01,   400000,     255,   0.45),
    (400000.01,   500000,     300,   0.4),
    (500000.01,   1000000,    340,   0.30),
    (1000000.01,  99999999,   490,   0.18),
]


def calcular_impuesto(monto):
    for desde, hasta, precio, adicional in tabla_impuestos:
        if desde <= monto <= hasta:
            valor = (monto - desde) / 1000 * adicional + precio
            return round(valor, 2)
    return None


def main():
    while True:
        print("\n" + "="*50)
        print("  CÁLCULO DE IMPUESTO A ACTIVIDADES ECONÓMICAS  ")
        print("="*50)
        print("  [1] Calcular impuesto")
        print("  [2] Salir")
        print("="*50)

        opcion = input("Seleccione una opción (1-2): ").strip()

        if opcion == "1":
            try:
                monto = float(input("\nIngrese el monto de la actividad económica: $"))

                if monto <= 0:
                    print("\nEl monto debe ser mayor a $0.00")
                    continue

                impuesto = calcular_impuesto(monto)

                if impuesto is not None:
                    print(f"\nEl valor a pagar por el impuesto es: ${impuesto:.2f}")
                else:
                    print("\nEl monto ingresado no se encuentra dentro de los rangos establecidos.")
            except ValueError:
                print("\nError: Por favor ingrese un valor numérico válido.")

        elif opcion == "2":
            print("\nSaliendo del programa...\n")
            break
        else:
            print("\nOpción no válida. Intente de nuevo.")


if __name__ == "__main__":
    main()
# Out:
# ==================================================
#   CÁLCULO DE IMPUESTO A ACTIVIDADES ECONÓMICAS
# ==================================================
#   [1] Calcular impuesto
#   [2] Salir
# ==================================================

# %% [markdown]
# # 2- CONVERSOR DE ÁREA #

# %%
# ==========================================
# CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# ==========================================

# 1. Diccionario con factores de conversión respecto al Metro Cuadrado (m²)
# (Factores estándar utilizados en El Salvador)
FACTORES_AREA = {
    "1": ("Pie Cuadrado (ft²)", 0.092903),
    "2": ("Vara Cuadrada (v²)", 0.698896),
     "3":("Yarda Cuadrada (yd²)", 0.836127),
    "4": ("Metro Cuadrado (m²)", 1.0),
    "5": ("Tarea", 628.8),
    "6": ("Manzana (mz)", 6988.96),
    "7": ("Hectárea (ha)", 10000.0)
}

# 2. Función de usuario para realizar el cálculo mediante lambdas
def calcular_conversion(valor, origen_key, destino_key):
    # Expresión lambda que convierte de unidad origen -> m² -> unidad destino
    a_metros = lambda x: x * FACTORES_AREA[origen_key][1]
    de_metros = lambda m2: m2 / FACTORES_AREA[destino_key][1]

    metros_cuadrados = a_metros(valor)
    return de_metros(metros_cuadrados)

# 3. Función de usuario para mostrar el menú desplegable
def mostrar_menu():
    print("\n" + "="*45)
    print("  CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR")
    print("="*45)
    for clave, (nombre, _) in FACTORES_AREA.items():
        print(f"  [{clave}] {nombre}")
    print("  [s] Salir")
    print("="*45)

# 4. Función principal que controla el flujo del programa
def ejecutar_conversor():
    while True:
        mostrar_menu()

        origen = input("Seleccione la unidad de ORIGEN: ").lower().strip()
        if origen == 's':
            print("\n¡Programa finalizado!")
            break

        if origen not in FACTORES_AREA:
            print(" Opción de origen no válida.")
            continue

        destino = input("Seleccione la unidad de DESTINO: ").lower().strip()
        if destino not in FACTORES_AREA:
            print(" Opción de destino no válida.")
            continue

        try:
            cantidad = float(input(f"Ingrese el valor en {FACTORES_AREA[origen][0]}: "))
            resultado = calcular_conversion(cantidad, origen, destino)

            print("\n" + "-"*45)
            print(f"RESULTADO: {cantidad} {FACTORES_AREA[origen][0]} = {resultado:,.4f} {FACTORES_AREA[destino][0]}")
            print("-"*45)
        except ValueError:
            print(" Error: Ingrese una cantidad numérica válida.")

# Ejecución del programa
if __name__ == "__main__":
    ejecutar_conversor()
# Out:
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# Seleccione la unidad de ORIGEN: 6
# Seleccione la unidad de DESTINO: 1
# Ingrese el valor en Manzana (mz): 10
#
# ---------------------------------------------
# RESULTADO: 10.0 Manzana (mz) = 752,285.7174 Pie Cuadrado (ft²)
# ---------------------------------------------
#
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# Seleccione la unidad de ORIGEN: 1
# Seleccione la unidad de DESTINO: 5
# Ingrese el valor en Pie Cuadrado (ft²): 5
#
# ---------------------------------------------
# RESULTADO: 5.0 Pie Cuadrado (ft²) = 0.0007 Tarea
# ---------------------------------------------
#
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# Seleccione la unidad de ORIGEN:
#  Opción de origen no válida.
#
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# Seleccione la unidad de ORIGEN:
#  Opción de origen no válida.
#
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# Seleccione la unidad de ORIGEN: 4
# Seleccione la unidad de DESTINO: 3
# Ingrese el valor en Metro Cuadrado (m²): 1
#
# ---------------------------------------------
# RESULTADO: 1.0 Metro Cuadrado (m²) = 1.1960 Yarda Cuadrada (yd²)
# ---------------------------------------------
#
# =============================================
#   CONVERSOR DE ÁREA (SUPERFICIE) - EL SALVADOR
# =============================================
#   [1] Pie Cuadrado (ft²)
#   [2] Vara Cuadrada (v²)
#   [3] Yarda Cuadrada (yd²)
#   [4] Metro Cuadrado (m²)
#   [5] Tarea
#   [6] Manzana (mz)
#   [7] Hectárea (ha)
#   [s] Salir
# =============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2049/3399292276.py in <cell line: 0>()
#      65 # Ejecución del programa
#      66 if __name__ == "__main__":
# ---> 67     ejecutar_conversor()
#
# /tmp/ipykernel_2049/3399292276.py in ejecutar_conversor()
#      39         mostrar_menu()
#      40
# ---> 41         origen = input("Seleccione la unidad de ORIGEN: ").lower().strip()
#      42         if origen == 's':
#      43             print("\n¡Programa finalizado!")
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # 3- SISTEMA ESTADÍSTICO

# %%
import math
from collections import Counter

# Dataset con 20 compañeros requeridos por la guía
estudiantes = [
    {"nombres": "Madison Odalis", "apellidos": "Valle Juárez", "edad": 20, "traslado": 30, "telefono": 8.5, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 9.0}},
    {"nombres": "Karen Elizabeth", "apellidos": "Ulloa Goméz", "edad": 18, "traslado": 40, "telefono": 9.0, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Flor Zulema", "apellidos": "Campos Orellana", "edad": 20, "traslado": 6, "telefono": 5.38, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Jimmy Arturo", "apellidos": "Marroquin Guzmán", "edad": 20, "traslado": 30, "telefono": 6.5, "materias": {"Programación III": 8.0, "Base de Datos II": 8.0, "Inglés Básico": 8.0, "Diseño de Circuitos Digitales": 8.0, "Estadística Computacional": 8.0}},
    {"nombres": "Diego Misael", "apellidos": "Villafranco Pineda", "edad": 20, "traslado": 30, "telefono": 8.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Yeimy Julissa", "apellidos": "Parada Chávez", "edad": 20, "traslado": 45, "telefono": 3.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Miguel Alejandro", "apellidos": "Gómez Saravia", "edad": 19, "traslado": 15, "telefono": 4.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Josué Stiven", "apellidos": "Funes Benavides", "edad": 19, "traslado": 30, "telefono": 5.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Jefferson Stiven", "apellidos": "Castillo Leiva", "edad": 19, "traslado": 15, "telefono": 2.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Ramael Ernesto", "apellidos": "Cordova Colindres", "edad": 22, "traslado": 7, "telefono": 13.52, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Carlos Daniel", "apellidos": "Parada Avalos", "edad": 25, "traslado": 10, "telefono": 5.52, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Carlos David", "apellidos": "Turcios Rivas", "edad": 20, "traslado": 25, "telefono": 5.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Gilda Mileidy", "apellidos": "González Castro", "edad": 19, "traslado": 30, "telefono": 5.92, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Samuel Alexander", "apellidos": "Portillo Cerón", "edad": 20, "traslado": 80, "telefono": 6.0, "materias": {"Programación III": 10.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Saúl Alexander", "apellidos": "Jimenez Garcia", "edad": 21, "traslado": 60, "telefono": 5.0, "materias": {"Programación III": 10.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.0}},
    {"nombres": "Edgar Ernesto", "apellidos": "Ramirez Barrera", "edad": 21, "traslado": 60, "telefono": 7.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 10.0}},
    {"nombres": "Jose Luis", "apellidos": "Garcia Mejia", "edad": 20, "traslado": 90, "telefono": 8.0, "materias": {"Programación III": 9.0, "Base de Datos II": 9.0, "Inglés Básico": 9.0, "Diseño de Circuitos Digitales": 8.0, "Estadística Computacional": 8.0}},
    {"nombres": "Jaime Shafik", "apellidos": "Salmeron Chicas", "edad": 20, "traslado": 7, "telefono": 6.0, "materias": {"Programación III": 8.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 8.0}},
    {"nombres": "Wilfredo Josue", "apellidos": "Ortez Gaitan", "edad": 20, "traslado": 30, "telefono": 5.0, "materias": {"Programación III": 9.0, "Base de Datos II": 10.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 10.0, "Estadística Computacional": 8.0}},
    {"nombres": "Andrea María", "apellidos": "López Rivas", "edad": 19, "traslado": 20, "telefono": 4.5, "materias": {"Programación III": 9.5, "Base de Datos II": 9.0, "Inglés Básico": 10.0, "Diseño de Circuitos Digitales": 9.0, "Estadística Computacional": 9.5}}
]

class EstadisticaEstudiantil:
    def __init__(self, datos):
        self.datos = datos

    def media(self, lista):
        return sum(lista) / len(lista)

    def mediana(self, lista):
        ordenados = sorted(lista)
        n = len(lista)
        mitad = n // 2
        return (ordenados[mitad - 1] + ordenados[mitad]) / 2 if n % 2 == 0 else ordenados[mitad]

    def moda(self, lista):
        conteo = Counter(lista)
        max_veces = max(conteo.values())
        if max_veces == 1:
            return "No hay moda"
        return [f"{num} (se repite {veces} veces)" for num, veces in conteo.items() if veces == max_veces]

    def varianza(self, lista):
        m = self.media(lista)
        return sum((x - m) ** 2 for x in lista) / (len(lista) - 1)

    def desviacion_estandar(self, lista):
        return math.sqrt(self.varianza(lista))

    def desviacion_tipica(self, lista):
        return self.desviacion_estandar(lista)

    def rango(self, lista):
        return max(lista) - min(lista)

    def frecuencia(self, lista):
        return dict(Counter(lista))

    def obtener_valores_y_mostrar(self, campo):
        valores = []
        print("\n--- DATOS ANALIZADOS ---")
        if campo == "nota":
            for est in self.datos:
                promedio = sum(est["materias"].values()) / len(est["materias"])
                valores.append(promedio)
                print(f"{est['nombres']} {est['apellidos']} -> Promedio General: {promedio:.2f} pts")
        elif campo == "traslado":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Traslado: {val} min")
        elif campo == "telefono":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Teléfono: {val} hrs")
        elif campo == "edad":
            for est in self.datos:
                val = est[campo]
                valores.append(val)
                print(f"{est['nombres']} {est['apellidos']} -> Edad: {val} años")
        return valores

    def elegir_campo(self):
        print("\n¿De cuál dato quieres calcular la estadística?")
        print("1. Notas (Promedio de materias)")
        print("2. Edades")
        print("3. Tiempo de traslado (minutos)")
        print("4. Horas de uso de teléfono")
        op = input("Elige una opción: ")
        opciones = {"1": "nota", "2": "edad", "3": "traslado", "4": "telefono"}
        return opciones.get(op, None)

    def ejecutar_menu(self):
        while True:
            print("\n==================================")
            print("   SISTEMA ESTADÍSTICO ACADÉMICO  ")
            print("==================================")
            print("1. Media aritmética")
            print("2. Mediana")
            print("3. Moda")
            print("4. Varianza")
            print("5. Desviación estándar")
            print("6. Desviación típica")
            print("7. Rango")
            print("8. Frecuencia")
            print("9. Ver explicación teórica (Diferencias)")
            print("0. Salir")

            opcion = input("Elige una opción: ")

            if opcion == "0":
                print("¡Hasta luego!")
                break
            elif opcion == "9":
                self.mostrar_explicacion_teorica()
                input("\nPresione Enter para volver al menú...")
                continue

            if opcion in [str(i) for i in range(1, 9)]:
                campo = self.elegir_campo()
                if campo is None:
                    print("Opción de campo no válida.")
                    continue

                valores = self.obtener_valores_y_mostrar(campo)

                print("\n==================================")
                print("       RESULTADO ESTADÍSTICO      ")
                print("==================================")
                if opcion == "1":
                    print(f"Media: {self.media(valores):.2f}")
                elif opcion == "2":
                    print(f"Mediana: {self.mediana(valores):.2f}")
                elif opcion == "3":
                    print(f"Moda: {self.moda(valores)}")
                elif opcion == "4":
                    print(f"Varianza: {self.varianza(valores):.2f}")
                elif opcion == "5":
                    print(f"Desviación estándar: {self.desviacion_estandar(valores):.2f}")
                elif opcion == "6":
                    print(f"Desviación típica: {self.desviacion_tipica(valores):.2f}")
                elif opcion == "7":
                    print(f"Rango: {self.rango(valores):.2f}")
                elif opcion == "8":
                    print(f"Frecuencia: {self.frecuencia(valores)}")

                input("\nPresione Enter para volver al menú...")
            else:
                print("Opción no válida. Intente de nuevo.")

    def mostrar_explicacion_teorica(self):
        print("\n-----------------------------------------------------------")
        print(" EXPLICACIÓN CON NUESTRAS PALABRAS DE LAS DIFERENCIAS ")
        print("-----------------------------------------------------------")
        print("1. Desviación Estándar vs. Desviación Típica:")
        print("   En estadística son exactamente lo mismo; ambos términos se usan ")
        print("   como sinónimos para referirse a la raíz cuadrada de la varianza.")
        print("\n2. Varianza vs. Desviación Estándar/Típica:")
        print("   - La Varianza mide qué tan dispersos están los datos elevando ")
        print("     las diferencias al cuadrado (ej. minutos al cuadrado).")
        print("   - La Desviación Estándar/Típica le saca raíz cuadrada a la varianza ")
        print("     para expresar la dispersión en las mismas unidades originales ")
        print("     (ej. minutos exactos o notas).")
        print("-----------------------------------------------------------\n")

if __name__ == "__main__":
    app = EstadisticaEstudiantil(estudiantes)
    app.ejecutar_menu()
# Out:
# ==================================
#    SISTEMA ESTADÍSTICO ACADÉMICO
# ==================================
# 1. Media aritmética
# 2. Mediana
# 3. Moda
# 4. Varianza
# 5. Desviación estándar
# 6. Desviación típica
# 7. Rango
# 8. Frecuencia
# 9. Ver explicación teórica (Diferencias)
# 0. Salir
# Elige una opción: 1
#
# ¿De cuál dato quieres calcular la estadística?
# 1. Notas (Promedio de materias)
# 2. Edades
# 3. Tiempo de traslado (minutos)
# 4. Horas de uso de teléfono
# Elige una opción: 3
#
# --- DATOS ANALIZADOS ---
# Madison Odalis Valle Juárez -> Traslado: 30 min
# Karen Elizabeth Ulloa Goméz -> Traslado: 40 min
# Flor Zulema Campos Orellana -> Traslado: 6 min
# Jimmy Arturo Marroquin Guzmán -> Traslado: 30 min
# Diego Misael Villafranco Pineda -> Traslado: 30 min
# Yeimy Julissa Parada Chávez -> Traslado: 45 min
# Miguel Alejandro Gómez Saravia -> Traslado: 15 min
# Josué Stiven Funes Benavides -> Traslado: 30 min
# Jefferson Stiven Castillo Leiva -> Traslado: 15 min
# Ramael Ernesto Cordova Colindres -> Traslado: 7 min
# Carlos Daniel Parada Avalos -> Traslado: 10 min
# Carlos David Turcios Rivas -> Traslado: 25 min
# Gilda Mileidy González Castro -> Traslado: 30 min
# Samuel Alexander Portillo Cerón -> Traslado: 80 min
# Saúl Alexander Jimenez Garcia -> Traslado: 60 min
# Edgar Ernesto Ramirez Barrera -> Traslado: 60 min
# Jose Luis Garcia Mejia -> Traslado: 90 min
# Jaime Shafik Salmeron Chicas -> Traslado: 7 min
# Wilfredo Josue Ortez Gaitan -> Traslado: 30 min
# Andrea María López Rivas -> Traslado: 20 min
#
# ==================================
#        RESULTADO ESTADÍSTICO
# ==================================
# Media: 33.00
#
# Presione Enter para volver al menú...
#
# ==================================
#    SISTEMA ESTADÍSTICO ACADÉMICO
# ==================================
# 1. Media aritmética
# 2. Mediana
# 3. Moda
# 4. Varianza
# 5. Desviación estándar
# 6. Desviación típica
# 7. Rango
# 8. Frecuencia
# 9. Ver explicación teórica (Diferencias)
# 0. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2049/2473072254.py in <cell line: 0>()
#     172 if __name__ == "__main__":
#     173     app = EstadisticaEstudiantil(estudiantes)
# --> 174     app.ejecutar_menu()
#
# /tmp/ipykernel_2049/2473072254.py in ejecutar_menu(self)
#     113             print("0. Salir")
#     114
# --> 115             opcion = input("Elige una opción: ")
#     116
#     117             if opcion == "0":
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
