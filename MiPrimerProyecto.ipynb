# %% [markdown]
# <a href="https://colab.research.google.com/github/Madison-gif6/PrograIII-Semi-2026/blob/main/MiPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "holaa"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)
booleano = True
print(booleano)
# Out:
# holaa Primera letra del saludo hola
# 5.25
# True

# %%
print("Sumar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# Sumar dos numeros:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3055/3351885904.py in <cell line: 0>()
#       1 print("Sumar dos numeros: ")
# ----> 2 num1 = input("Num 1: ")
#       3 num2 = input("Num 2: ")
#       4 respuesta = float(num1) + float(num2)
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
print("Restar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) - float(num2)

print("Respuesta: ", respuesta)
# Out:
# Restar dos numeros:

# %%
print("Multiplicar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) * float(num2)

print("Respuesta: ", respuesta)
# Out:
# Multiplicar dos numeros:
# Num 1: 5
# Num 2: 3
# Respuesta:  15.0

# %%
print("Dividir dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) / float(num2)

print("Respuesta: ", respuesta)
# Out:
# Dividir dos numeros:
# Num 1: 6
# Num 2: 2
# Respuesta:  3.0

# %%
saludo = "holaa"
print("Primer Elemento de la cadena", saludo[0])
print("Rango en una cadena", saludo[0:4])
print("Ultimo elemento", saludo[-1])
print("Ultimo elemento", saludo[len(saludo)-1])
print("Valores en medio, sin especificar ultimo valor", saludo[5:])
print("Sin valor al inicio, saludo"[:4])
print("Contar del final", saludo[6:-1])
# Out:
# Primer Elemento de la cadena h
# Rango en una cadena hola
# Ultimo elemento a
# Ultimo elemento a
# Valores en medio, sin especificar ultimo valor
# Sin
# Contar del final

# %% [markdown]
# **FUNCIONES EN PYTHON**

# %%
def suma(num1,num2):
    return float(num1) + float(num2)
    return respuesta

# %%
def suma(num1,num2):
    return float(num1) - float(num2)
    return respuesta

# %%
 num1 = input("Num 1: ")
 num2 = input("Num 2: ")
 print("La suma: ", suma(num1,num2))
 print("La Resta: ", suma(num1,num2))
# Out:
# Num 1:
# Num 2:
# La suma:
# La Resta:

# %% [markdown]
# Hacer el siguiente ejercicio en python haciendo uso de funciones, que convierta grados celcius a ferenheit

# %%
def convertir(celcius):
    return float(celcius)*9/5 + 32

# %%
c = input("Grados Celcius: ")
print("Grados Ferenheit:", convertir(c))
# Out:
# Grados Celcius: 33
# Grados Ferenheit: 91.4

# %%
def convertir(ferenheit):
    return (float(ferenheit)-32) *5/9

# %%
f = input("Grados Ferenheit: ")
print("Grados Celcius:", convertir(f))
# Out:
# Grados Ferenheit: 91
# Grados Celcius: 32.77777777777778

# %%
def convertir(Celcius):
    return float(Celcius) + 273.15

c = input("Grados Celcius: ")
print("Grados Kelvin:", convertir(c))
# Out:
# Grados Celcius: 33
# Grados Kelvin: 306.15

# %% [markdown]
# Funciones anónimas

# %%
convertir = lambda c: float(c)*9/5 + 32

# %%
c = float(input("Grados Celcius: "))
print("Grados Ferenheit:", convertir(c))
# Out:
# Grados Celcius: 33
# Grados Ferenheit: 91.4
